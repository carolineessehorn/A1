# %%
! cowsay hello
# Out:
# /home/ubuntu/bin/cowsay: line 9: syntax error near unexpected token `('
# /home/ubuntu/bin/cowsay: line 9: `use Text::Tabs qw(expand);'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area()
plt.show()
